# %% [markdown]
# # PyCaret 2 Classification

# %%
# Installing pycarat full version

# !pip install pycaret[full]

# %% [markdown]
# # Data Repository

# %%
# Get data
from pycaret.datasets import get_data
from pycaret.classification import *
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# # Initialize Setup

# %%
data = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 2      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 3      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
# 4      0      0    64400.0    57069.0    57608.0    19394.0    19619.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
clf1 = setup(data, target = 'default', session_id=123, log_experiment=True, experiment_name='credit')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            16:36:04
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#              Data Type
# LIMIT_BAL      Numeric
# SEX        Categorical
# EDUCATION  Categorical
# MARRIAGE   Categorical
# AGE            Numeric
# PAY_1      Categorical
# PAY_2      Categorical
# PAY_3      Categorical
# PAY_4      Categorical
# PAY_5      Categorical
# PAY_6      Categorical
# BILL_AMT1      Numeric
# BILL_AMT2      Numeric
# BILL_AMT3      Numeric
# BILL_AMT4      Numeric
# BILL_AMT5      Numeric
# BILL_AMT6      Numeric
# PAY_AMT1       Numeric
# PAY_AMT2       Numeric
# PAY_AMT3       Numeric
# PAY_AMT4       Numeric
# PAY_AMT5       Numeric
# PAY_AMT6       Numeric
# default          Label

# %% [markdown]
# # Compare Baseline

# %%
best_model = compare_models(fold=5)
# Out:
# <style  type="text/css" >
#     #T_216e3034_9509_11eb_842c_f40f243a1dca th {
#           text-align: left;
# ...

# %%
qda = create_model('qda')
# Out:
# <style  type="text/css" >
# #T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col0,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col1,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col2,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col3,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col4,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col5,#T_5114289e_9506_11eb_a2a3_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_5114289e_9506_11eb_a2a3_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
nb = create_model('nb')
# Out:
# <style  type="text/css" >
# #T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col0,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col1,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col2,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col3,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col4,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col5,#T_41bd3a40_9509_11eb_977e_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_41bd3a40_9509_11eb_977e_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col0,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col1,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col2,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col3,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col4,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col5,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_87fe65cc_940c_11eb_a222_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
rf = create_model('rf', fold = 5)
# Out:
# <style  type="text/css" >
# #T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col0,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col1,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col2,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col3,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col4,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col5,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col6{
#             background:  yellow;
#         }</style><table id="T_9439abc6_940c_11eb_a03c_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
models(type='ensemble').index.tolist()
# Out:
# ['rf', 'ada', 'gbc', 'et', 'xgboost', 'lightgbm', 'catboost']

# %% [markdown]
# # Tune Hyperparameters

# %%
tuned_nb = tune_model(nb)
# Out:
# <style  type="text/css" >
# #T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col0,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col1,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col2,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col3,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col4,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col5,#T_479f178a_9509_11eb_a36d_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_479f178a_9509_11eb_a36d_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(nb)

# %%
plot_model(nb, plot = 'confusion_matrix')

# %%
plot_model(nb, plot = 'boundary')

# %%
plot_model(nb, plot = 'class_report')
