# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# Load a numpy record array from yahoo csv data with fields date, open, close,
# volume, adj_close from the mpl-data/example directory. The record array
# stores the date as an np.datetime64 with a day unit ('D') in the date column.
price_data = (cbook.get_sample_data('goog.npz', np_load=True)['price_data']
              .view(np.recarray))
price_data = price_data[-250:]  # get the most recent 250 trading days

delta1 = np.diff(price_data.adj_close) / price_data.adj_close[:-1]

# Marker size in units of points^2
volume = (15 * price_data.volume[:-2] / price_data.volume[0])**2
close = 0.003 * price_data.close[:-2] / 0.003 * price_data.open[:-2]

fig, ax = plt.subplots()
ax.scatter(delta1[:-1], delta1[1:], c=close, s=volume, alpha=0.5)

ax.set_xlabel(r'$\Delta_i$', fontsize=15)
ax.set_ylabel(r'$\Delta_{i+1}$', fontsize=15)
ax.set_title('Volume and percent change')

ax.grid(True)
fig.tight_layout()

plt.show()

# %% [markdown]
# # TPOT

# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 3.5 MB/s eta 0:00:011
# Collecting deap>=1.2
#   Downloading deap-1.3.1-cp38-cp38-macosx_10_14_x86_64.whl (109 kB)
#      |████████████████████████████████| 109 kB 17.6 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.36.1 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (4.61.2)
# Requirement already satisfied: pandas>=0.24.2 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.3.0)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: numpy>=1.16.3 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.21.0)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (0.24.2)
# Requirement already satisfied: xgboost>=1.1.0 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.4.2)
# Requirement already satisfied: scipy>=1.3.1 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.7.0)
# Requirement already satisfied: joblib>=0.13.2 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: requests>=2.3.0 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.6)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11955 sha256=45885fb2dafbda4583a5dcd3ab8581661d59eb56ac980dc819a2df3f0804533d
#   Stored in directory: /Users/ismaeltrevi/Library/Caches/pip/wheels/a8/bb/8f/6b9328d23c2dcedbfeb8498b9f650d55d463089e3b8fc0bfb2
# Successfully built stopit
# Installing collected packages: update-checker, stopit, deap, tpot
# Successfully installed deap-1.3.1 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.3 is available.
# You should consider upgrading via the '/Users/ismaeltrevi/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from tpot import TPOTClassifier
# Out:
# /Users/ismaeltrevi/opt/anaconda3/lib/python3.8/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
