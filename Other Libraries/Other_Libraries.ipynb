# %% [markdown]
# # PyForest

# %%
# !pip install pyforest

# %%
from pyforest import *

# %%
lazy_imports()
# Out:
# ['import tensorflow as tf',
#  'import pydot',
#  'from sklearn.ensemble import GradientBoostingRegressor',
#  'import re',
#  'from pyspark import SparkContext',
#  'import sklearn',
#  'import tqdm',
#  'import sys',
#  'import nltk',
#  'import matplotlib as mpl',
#  'from openpyxl import load_workbook',
#  'import plotly as py',
#  'from sklearn.ensemble import RandomForestRegressor',
#  'import pandas as pd',
#  'import dash',
#  'from sklearn.ensemble import RandomForestClassifier',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'from sklearn.preprocessing import OneHotEncoder',
#  'import xgboost as xgb',
#  'import plotly.express as px',
#  'import spacy',
#  'import plotly.graph_objs as go',
#  'import numpy as np',
#  'import bokeh',
#  'import awswrangler as wr',
#  'import keras',
#  'from sklearn.manifold import TSNE',
#  'import datetime as dt',
#  'from sklearn.model_selection import train_test_split',
#  'import gensim',
#  'from pathlib import Path',
#  'import altair as alt',
#  'from sklearn import svm',
#  'from sklearn.linear_model import LogisticRegression',
#  'from dask import dataframe as dd',
#  'import pickle',
#  'import matplotlib.pyplot as plt',
#  'import seaborn as sns',
#  'import statistics',
#  'import lightgbm as lgb',
#  'from sklearn.linear_model import LinearRegression',
#  'import os',
#  'import glob',
#  'from sklearn.ensemble import GradientBoostingClassifier']

# %% [markdown]
# # Geemap

# %%
# !pip install geemap

# %%
# import geemap

# %%
import geemap.eefolium as geemap
Map = geemap.Map(center=[40,-100], zoom=4)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Emot

# %%
# !pip install emot

# %%
import emot

# %%
text = 'I ❤️ Python 🙂'

# %%
ans = emot.emoji(text)
ans
# Out:
# {'value': ['❤', '🙂'],
#  'mean': [':red_heart:', ':slightly_smiling_face:'],
#  'location': [[2, 2], [12, 12]],
#  'flag': True}

# %%
ans['value']
# Out:
# ['❤', '🙂']

# %%
ans['location']
# Out:
# [[2, 2], [12, 12]]

# %%
ans['mean']
# Out:
# [':red_heart:', ':slightly_smiling_face:']

# %%
text = 'I love Python :)'
emot.emoticons(text)
# Out:
# {'value': [':)'],
#  'location': [[14, 16]],
#  'mean': ['Happy face or smiley'],
#  'flag': True}

# %%
text = ':('
emot.emoticons(text)
# Out:
# {'value': [':('],
#  'location': [[0, 2]],
#  'mean': ['Frown, sad, andry or pouting'],
#  'flag': True}

# %% [markdown]
# # Dabl

# %%
# !pip install dabl

# %%
import dabl

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('loans.csv')

# %%
dabl.clean(df, verbose=2).head(2)
# Out:
# Detected feature types:
# continuous      8
# dirty_float     0
# low_card_int    2
# categorical     8
# date            1
# free_string     5
# useless         1
# dtype: int64
#            Name               Email ID  Gender Dt_Applied  \
# 0  Calley Giron       cgiron0@ehow.com  Female     1/1/81
# 1    Linus Stud  lstud1@washington.edu    Male     2/1/81
#
#                                           University  Loan Amnt  \
# 0                            Warner Southern College       5000
# 1  Shri Lal Bahadur Shastri Rashtriya Sanskrit Vi...       2500
#
#    Funded amnt inv        TERM  Int Rate  INSTALLMENT  ...  \
# 0           4975.0   36 months     0.107       162.87  ...
# 1           2500.0   60 months     0.153        59.83  ...
#
#   Verification Status Loan Writeoff      PURPOSE  Zip Code Add State    DTI  \
# 0            Verified             0  credit_card     860xx        AZ  27.65
# 1     Source Verified             1          car     309xx        GA   1.00
#
#   Delinq 2Yrs Inq Last 6Mths Revol Bal  Total Paymnt
# 0           0              1     13648   5863.155187
# 1           0              5      1687   1014.530000
#
# [2 rows x 24 columns]

# %%
dabl.plot(df, 'PURPOSE')
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/supervised.py:547: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   FutureWarning)
# Target looks like classification
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:633: UserWarning: Dropped 8 outliers in column Annual Inc.
#   int(dropped), series.name), UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:633: UserWarning: Dropped 9 outliers in column Revol Bal.
#   int(dropped), series.name), UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:633: UserWarning: Dropped 15 outliers in column Inq Last 6Mths.
#   int(dropped), series.name), UserWarning)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:633: UserWarning: Dropped 5 outliers in column Delinq 2Yrs.
#   int(dropped), series.name), UserWarning)
# Linear Discriminant Analysis training set score: 0.092
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/dabl/plot/utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]

# %%
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
sc = dabl.SimpleClassifier().fit(X_train, y_train)
print("Accuracy score", sc.score(X_test, y_test))
# Out:
# Running DummyClassifier()
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
# === new best DummyClassifier() (using recall_macro):
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
#
# Running GaussianNB()
# accuracy: 0.814 recall_macro: 0.815 precision_macro: 0.826 f1_macro: 0.817
# === new best GaussianNB() (using recall_macro):
# accuracy: 0.814 recall_macro: 0.815 precision_macro: 0.826 f1_macro: 0.817
#
# Running MultinomialNB()
# accuracy: 0.904 recall_macro: 0.905 precision_macro: 0.909 f1_macro: 0.905
# === new best MultinomialNB() (using recall_macro):
# accuracy: 0.904 recall_macro: 0.905 precision_macro: 0.909 f1_macro: 0.905
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.196 recall_macro: 0.199 precision_macro: 0.076 f1_macro: 0.099
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=10)
# accuracy: 0.828 recall_macro: 0.828 precision_macro: 0.833 f1_macro: 0.828
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.777 recall_macro: 0.778 precision_macro: 0.786 f1_macro: 0.778
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.965
# === new best LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000) (using recall_macro):
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.965
#
# Running LogisticRegression(class_weight='balanced', max_iter=1000)
# accuracy: 0.963 recall_macro: 0.963 precision_macro: 0.964 f1_macro: 0.963
#
# Best model:
# LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# Best Scores:
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.965
# Accuracy score 0.9777777777777777

# %% [markdown]
# ## Testing results with Scikit-Learn

# %%
# Iterating through Logistic Regression Model
log_reg = LogisticRegression(class_weight='balanced', max_iter=1000)

# Fitting model to the train set
log_reg.fit(X_train, y_train)

# Predicting with the Test set
y_pred = log_reg.predict(X_test)

# Printing accuracy score
print('Accuracy score: ' + str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.9688888888888889
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# # Sweetviz

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
