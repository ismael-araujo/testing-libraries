# %% [markdown]
# # PyForest

# %%
# !pip install pyforest

# %%
from pyforest import *

# %%
lazy_imports()
# Out:
# ['import pandas as pd',
#  'import glob',
#  'import awswrangler as wr',
#  'import lightgbm as lgb',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'from sklearn.ensemble import GradientBoostingClassifier',
#  'from sklearn.linear_model import LinearRegression',
#  'import os',
#  'import tensorflow as tf',
#  'import statistics',
#  'import gensim',
#  'from openpyxl import load_workbook',
#  'import plotly.express as px',
#  'import nltk',
#  'from sklearn.preprocessing import OneHotEncoder',
#  'from sklearn import svm',
#  'from sklearn.linear_model import LogisticRegression',
#  'import pydot',
#  'import seaborn as sns',
#  'from sklearn.model_selection import train_test_split',
#  'import sys',
#  'import matplotlib as mpl',
#  'import datetime as dt',
#  'from pyspark import SparkContext',
#  'import plotly.graph_objs as go',
#  'from sklearn.ensemble import RandomForestClassifier',
#  'import spacy',
#  'import plotly as py',
#  'import pickle',
#  'import sklearn',
#  'from sklearn.ensemble import GradientBoostingRegressor',
#  'from sklearn.manifold import TSNE',
#  'import altair as alt',
#  'from dask import dataframe as dd',
#  'import xgboost as xgb',
#  'import bokeh',
#  'from sklearn.ensemble import RandomForestRegressor',
#  'import matplotlib.pyplot as plt',
#  'import numpy as np',
#  'import re',
#  'from pathlib import Path',
#  'import tqdm',
#  'import dash',
#  'import keras']

# %% [markdown]
# # Geemap

# %%
# !pip install geemap

# %%
import geemap

# %%
import geemap.eefolium as geemap
Map = geemap.Map(center=[40,-100], zoom=4)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Emot

# %%
# !pip install emot

# %%
import emot

# %%
text = 'I love Python ❤️'

# %%
ans = emot.emoji(text)
ans
# Out:
# {'value': ['❤'], 'mean': [':red_heart:'], 'location': [[14, 14]], 'flag': True}

# %%
ans['value']
# Out:
# ['❤']

# %%
ans['location']
# Out:
# [[14, 14]]

# %%
ans['mean']
# Out:
# [':red_heart:']

# %%
text = 'I love Python :)'
emot.emoticons(text)
# Out:
# {'value': [':)'],
#  'location': [[14, 16]],
#  'mean': ['Happy face or smiley'],
#  'flag': True}

# %%
emot.emoticons("I don't like cockroaches :( 😩")
# Out:
# {'value': [':('],
#  'location': [[25, 27]],
#  'mean': ['Frown, sad, andry or pouting'],
#  'flag': True}

# %% [markdown]
# # Dabl

# %%
# !pip install dabl

# %%
import dabl

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.metrics import accuracy_score

# %%
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
sc = dabl.SimpleClassifier().fit(X_train, y_train)
print("Accuracy score", sc.score(X_test, y_test))
# Out:
# Running DummyClassifier()
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
# === new best DummyClassifier() (using recall_macro):
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
#
# Running GaussianNB()
# accuracy: 0.806 recall_macro: 0.807 precision_macro: 0.820 f1_macro: 0.808
# === new best GaussianNB() (using recall_macro):
# accuracy: 0.806 recall_macro: 0.807 precision_macro: 0.820 f1_macro: 0.808
#
# Running MultinomialNB()
# accuracy: 0.909 recall_macro: 0.909 precision_macro: 0.914 f1_macro: 0.910
# === new best MultinomialNB() (using recall_macro):
# accuracy: 0.909 recall_macro: 0.909 precision_macro: 0.914 f1_macro: 0.910
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.196 recall_macro: 0.199 precision_macro: 0.076 f1_macro: 0.099
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=10)
# accuracy: 0.823 recall_macro: 0.823 precision_macro: 0.831 f1_macro: 0.824
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.789 recall_macro: 0.791 precision_macro: 0.803 f1_macro: 0.790
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.965 f1_macro: 0.964
# === new best LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000) (using recall_macro):
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.965 f1_macro: 0.964
#
# Running LogisticRegression(class_weight='balanced', max_iter=1000)
# accuracy: 0.963 recall_macro: 0.963 precision_macro: 0.964 f1_macro: 0.963
#
# Best model:
# LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# Best Scores:
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.965 f1_macro: 0.964
# Accuracy score 0.9777777777777777

# %% [markdown]
# ## Testing results with Scikit-Learn

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

# %%
log_reg = LogisticRegression(class_weight='balanced', max_iter=1000)
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

# %%
score = log_reg.score(X_test, y_test)
print(score)
# Out:
# 0.9688888888888889

# %%
print('Accuracy score: ' + str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy score: 0.9688888888888889

# %% [markdown]
# ## Plotting with Dabl

# %%
dabl.plot(X, y)
# Out:
# Target looks like classification
# Showing only top 10 of 50 continuous features
# Linear Discriminant Analysis training set score: 0.963

# %%
from numerize import numerize as numerizer
create

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-e80b5ecc51ca> in <module>
# ----> 1 numerizer()
#
# TypeError: 'module' object is not callable
