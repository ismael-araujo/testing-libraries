# %%
import pyforest

# Hide warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('worldcitiespop.csv')

# %%
df.head()

# %%
us = df[df['Country'] == 'us']

# %%
us['City'] = us['City'].str.title()

# %%
cities = us[['City', 'Population']].nlargest(15, ['Population'], keep='first')

# %%
x = cities['City']
y = cities['Population']

# %%
hfont = {'fontname':'Helvetica'}

# %%
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))

# %%
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))
plt.show()

# %%
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))
plt.xticks(rotation=45)
plt.show()

# %%
# sns.set_style("darkgrid")
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))
plt.xticks(rotation=45)
plt.show()

# %%
# sns.set_style("darkgrid")
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))
plt.xticks(rotation=45)
plt.show()

# %%
# sns.set_style("darkgrid")
sns.color_palette("Paired")
cities.plot.bar(x='City', y='Population', rot=0, figsize=(18, 8))
plt.title('Largest Cities in the US', fontsize=18, fontdict={'fontname':'Helvetica'})
plt.xlabel('Cities', fontsize=18, fontdict={'fontname':'Helvetica'})
plt.xticks(fontsize=16, rotation=45)
plt.yticks(fontsize=16)
plt.show()

# %%
# sns.set_style("darkgrid")
sns.color_palette("Blues", 12)
cities.plot.bar(x='City', y='Population', figsize=(18, 8))
plt.title('Largest Cities in the US', fontsize=18, fontdict={'fontname':'Helvetica'})
plt.xlabel('Cities', fontsize=22, fontdict={'fontname':'Helvetica'})
plt.xticks(fontsize=16, rotation=45)
plt.show()

# %%
plt.yticks(np.arange(y.min(), y.max(), 0.005))
plt.plot(x, y)
