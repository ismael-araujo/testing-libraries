# %% [markdown]
# # PyCaret 2 Classification

# %%
# Installing pycarat full version

# !pip install pycaret[full]

# %% [markdown]
# # Data Repository

# %%
# Get data
from pycaret.datasets import get_data
from pycaret.classification import *
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# # Initialize Setup

# %%
data = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 2      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 3      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
# 4      0      0    64400.0    57069.0    57608.0    19394.0    19619.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
clf1 = setup(data, target = 'default', session_id=123, log_experiment=True, experiment_name='juice1')
# Out:
# <style  type="text/css" >
# #T_32cffb2e_940c_11eb_98b7_f40f243a1dcarow19_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_32cffb2e_940c_11eb_98b7_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32cffb2e_940c_11eb_98b7_f40f243a1dcalevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_32cffb2e_940c_11eb_98b7_f40f243a1dcarow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_32cffb2e_940c_11eb_98b7_f40f243a1dcarow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_32cffb2e_940c_11eb_98b7_f40f243a1dcalevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# # Compare Baseline

# %%
best_model = compare_models(fold=5)
# Out:
# <style  type="text/css" >
#     #T_73bc584c_940c_11eb_aa80_f40f243a1dca th {
#           text-align: left;
# ...

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col0,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col1,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col2,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col3,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col4,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col5,#T_76e78aca_940c_11eb_8680_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_76e78aca_940c_11eb_8680_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col0,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col1,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col2,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col3,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col4,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col5,#T_87fe65cc_940c_11eb_a222_f40f243a1dcarow10_col6{
#             background:  yellow;
#         }</style><table id="T_87fe65cc_940c_11eb_a222_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
rf = create_model('rf', fold = 5)
# Out:
# <style  type="text/css" >
# #T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col0,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col1,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col2,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col3,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col4,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col5,#T_9439abc6_940c_11eb_a03c_f40f243a1dcarow5_col6{
#             background:  yellow;
#         }</style><table id="T_9439abc6_940c_11eb_a03c_f40f243a1dca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
models(type='ensemble').index.tolist()
# Out:
# ['rf', 'ada', 'gbc', 'et', 'xgboost', 'lightgbm', 'catboost']

# %%
# ensembled_models = compare_models(whitelist = models(type='ensemble').index.tolist(), fold = 3)
